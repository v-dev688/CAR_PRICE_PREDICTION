# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
car=pd.read_csv("/content/quikr_car.csv")
car.head()
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel

# %%
car.shape
# Out:
# (892, 6)

# %%
sorted(car['year'].unique())
# Out:
# [', Ac',
#  '...',
#  '/-Rs',
#  '150k',
#  '1995',
#  '2 bs',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  'D...',
#  'EV2',
#  'Eon',
#  'SALE',
#  'SELL',
#  'Sumo',
#  'TOUR',
#  'Zest',
#  'able',
#  'ara)',
#  'arry',
#  'cab',
#  'car',
#  'cent',
#  'd Ex',
#  'd...',
#  'digo',
#  'e...',
#  'emi',
#  'go .',
#  'k...',
#  'n...',
#  'no.',
#  'o c4',
#  'o...',
#  'odel',
#  'r 15',
#  'r...',
#  'sale',
#  'sell',
#  't xe',
#  'tion',
#  'ture',
#  'zest',
#  'zire']

# %%
sorted(car['Price'].unique())
# Out:
# ['1,00,000',
#  '1,05,000',
#  '1,10,000',
#  '1,14,990',
#  '1,15,000',
#  '1,20,000',
#  '1,23,000',
#  '1,25,000',
#  '1,30,000',
#  '1,35,000',
#  '1,40,000',
#  '1,45,000',
#  '1,49,000',
#  '1,50,000',
#  '1,55,000',
#  '1,55,555',
#  '1,58,400',
#  '1,59,000',
#  '1,59,500',
#  '1,60,000',
#  '1,62,000',
#  '1,65,000',
#  '1,68,000',
#  '1,69,500',
#  '1,69,999',
#  '1,70,000',
#  '1,74,999',
#  '1,75,000',
#  '1,78,000',
#  '1,79,000',
#  '1,79,999',
#  '1,80,000',
#  '1,82,000',
#  '1,85,000',
#  '1,88,000',
#  '1,89,000',
#  '1,89,500',
#  '1,89,700',
#  '1,90,000',
#  '1,95,000',
#  '1,99,000',
#  '1,99,999',
#  '10,00,000',
#  '10,25,000',
#  '10,65,000',
#  '10,74,999',
#  '10,75,000',
#  '11,30,000',
#  '11,50,000',
#  '12,00,000',
#  '12,25,000',
#  '12,99,000',
#  '13,50,000',
#  '14,00,000',
#  '14,75,000',
#  '14,90,000',
#  '14,99,000',
#  '15,00,000',
#  '15,10,000',
#  '15,25,000',
#  '15,40,000',
#  '15,99,000',
#  '16,00,000',
#  '17,25,000',
#  '18,50,000',
# ...

# %%
sorted(car['company'].unique())
# Out:
# ['2012',
#  '7',
#  '9',
#  'Any',
#  'Audi',
#  'BMW',
#  'Chevrolet',
#  'Commercial',
#  'Datsun',
#  'Fiat',
#  'Force',
#  'Ford',
#  'Hindustan',
#  'Honda',
#  'Hyundai',
#  'I',
#  'Jaguar',
#  'Jeep',
#  'Land',
#  'MARUTI',
#  'Mahindra',
#  'Maruti',
#  'Mercedes',
#  'Mini',
#  'Mitsubishi',
#  'Nissan',
#  'Renault',
#  'Sale',
#  'Skoda',
#  'Swift',
#  'TATA',
#  'Tara',
#  'Tata',
#  'Toyota',
#  'URJENT',
#  'Used',
#  'Volkswagen',
#  'Volvo',
#  'Well',
#  'Yamaha',
#  'all',
#  'i',
#  'scratch',
#  'sell',
#  'selling',
#  'tata',
#  'urgent',
#  'very']

# %%
car['kms_driven'].unique()
# Out:
# array(['45,000 kms', '40 kms', '22,000 kms', '28,000 kms', '36,000 kms',
#        '59,000 kms', '41,000 kms', '25,000 kms', '24,530 kms',
#        '60,000 kms', '30,000 kms', '32,000 kms', '48,660 kms',
#        '4,000 kms', '16,934 kms', '43,000 kms', '35,550 kms',
#        '39,522 kms', '39,000 kms', '55,000 kms', '72,000 kms',
#        '15,975 kms', '70,000 kms', '23,452 kms', '35,522 kms',
#        '48,508 kms', '15,487 kms', '82,000 kms', '20,000 kms',
#        '68,000 kms', '38,000 kms', '27,000 kms', '33,000 kms',
#        '46,000 kms', '16,000 kms', '47,000 kms', '35,000 kms',
#        '30,874 kms', '15,000 kms', '29,685 kms', '1,30,000 kms',
#        '19,000 kms', nan, '54,000 kms', '13,000 kms', '38,200 kms',
#        '50,000 kms', '13,500 kms', '3,600 kms', '45,863 kms',
#        '60,500 kms', '12,500 kms', '18,000 kms', '13,349 kms',
#        '29,000 kms', '44,000 kms', '42,000 kms', '14,000 kms',
#        '49,000 kms', '36,200 kms', '51,000 kms', '1,04,000 kms',
# ...

# %%
# convert to lower case and sort
sorted(car['name'].unique())
# Out:
# ['2012 Tata Sumo Gold f',
#  '7 SEATER MAHINDRA BOLERO IN VERY GOOD',
#  '9 SEATER MAHINDRA BOL',
#  'Any type car avaiabel hare...comercica',
#  'Audi A3 Cabriolet 40 TFSI',
#  'Audi A4 1.8 TFSI Multitronic Premium Plus',
#  'Audi A4 2.0 TDI 177bhp Premium',
#  'Audi A6 2.0 TDI Premium',
#  'Audi A8',
#  'Audi Q3 2.0 TDI quattro Premium',
#  'Audi Q5 2.0 TDI quattro Premium Plus',
#  'Audi Q7',
#  'BMW 3 Series 320d Sedan',
#  'BMW 3 Series 320i',
#  'BMW 5 Series 520d Sedan',
#  'BMW 5 Series 530i',
#  'BMW 7 Series 740Li Sedan',
#  'BMW X1',
#  'BMW X1 sDrive20d',
#  'BMW X1 xDrive20d xLine',
#  'Chevrolet Beat',
#  'Chevrolet Beat Diesel',
#  'Chevrolet Beat LS Diesel',
#  'Chevrolet Beat LS Petrol',
#  'Chevrolet Beat LT Diesel',
#  'Chevrolet Beat LT Opt Diesel',
#  'Chevrolet Beat LT Petrol',
#  'Chevrolet Beat PS Diesel',
#  'Chevrolet Cruze LTZ',
#  'Chevrolet Cruze LTZ AT',
#  'Chevrolet Enjoy',
#  'Chevrolet Enjoy 1.4 LS 8 STR',
#  'Chevrolet Sail 1.2 LS',
# ...

# %%
car['fuel_type'].unique()
# Out:
# array(['Petrol', 'Diesel', nan, 'LPG'], dtype=object)

# %% [markdown]
# 1. car['year'] - all values are not in integer
# 2. car['Price'] - Need to change into integers- 'Ask for price', remove commas
# 3. car['company']- Some values are not company names
# 4. car['kms_driven'] - 'petrol' value and need to convert to integers
# 5.car['name']<br>
# I want to sell my commercial car due t<br>
# i want sale my car.no emi....uber atta<br>
# Tata ZEST 6 month old<br>
# all paper updated tata indica v2 and u<br>
# Well mentained Tata Sumo<br>
# scratch less Tata I<br>
# sell my car Maruti Suzuki Swif<br>
# Maruti Suzuki Swift Dzire good car fo<br>
# urgent sale Ta<br>
# Maruti Suzuki Swift Select Variant<br>
# Any type car avaiabel hare...comercica<br>

# %% [markdown]
# <h1><b>Cleaning the data

# %%
backup =car.copy()

# %%
backup.head()
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel

# %%
car=backup.copy()

# %%
#filter out cars that have years
car=car[car['year'].str.isnumeric()]
car
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 886                    Toyota Corolla Altis     Toyota  2009       3,00,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#        kms_driven fuel_type
# ...

# %%
#convert to integer
car['year'].astype(int)
# Out:
# 0      2007
# 1      2006
# 2      2018
# 3      2014
# 4      2014
#        ...
# 886    2009
# 888    2018
# 889    2013
# 890    2014
# 891    2014
# Name: year, Length: 842, dtype: int64

# %%
car.head()
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel

# %%
car['year'].isnull().sum()
# Out:
# 0

# %%
car=car[car['Price']!='Ask For Price']
car.head()
# Out:
#                                      name   company  year     Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007    80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006  4,25,000
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014  5,75,000
# 6                               Ford Figo      Ford  2012  1,75,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel
# 6  41,000 kms    Diesel

# %%
car['Price']=car['Price'].str.replace(",","").astype(int)
# Out:
# <ipython-input-127-b6f8189367d4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car['Price']=car['Price'].str.replace(",","").astype(int)

# %%
car['Price'].astype(int)
# Out:
# 0       80000
# 1      425000
# 3      325000
# 4      575000
# 6      175000
#         ...
# 886    300000
# 888    260000
# 889    390000
# 890    180000
# 891    160000
# Name: Price, Length: 819, dtype: int64

# %%
car['year'].astype(int)
# Out:
# 0      2007
# 1      2006
# 3      2014
# 4      2014
# 6      2012
#        ...
# 886    2009
# 888    2018
# 889    2013
# 890    2014
# 891    2014
# Name: year, Length: 819, dtype: int64

# %%
car["year"] = car["year"].astype(str).astype(int)
# Out:
# <ipython-input-130-a6ed981271d7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car["year"] = car["year"].astype(str).astype(int)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 819 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        819 non-null    object
#  1   company     819 non-null    object
#  2   year        819 non-null    int64
#  3   Price       819 non-null    int64
#  4   kms_driven  819 non-null    object
#  5   fuel_type   816 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 44.8+ KB

# %%
car['kms_driven'].unique()
# Out:
# array(['45,000 kms', '40 kms', '28,000 kms', '36,000 kms', '41,000 kms',
#        '25,000 kms', '24,530 kms', '60,000 kms', '30,000 kms',
#        '32,000 kms', '48,660 kms', '4,000 kms', '16,934 kms',
#        '43,000 kms', '35,550 kms', '39,522 kms', '39,000 kms',
#        '55,000 kms', '72,000 kms', '15,975 kms', '70,000 kms',
#        '23,452 kms', '35,522 kms', '48,508 kms', '15,487 kms',
#        '82,000 kms', '20,000 kms', '68,000 kms', '38,000 kms',
#        '27,000 kms', '33,000 kms', '46,000 kms', '16,000 kms',
#        '47,000 kms', '35,000 kms', '30,874 kms', '15,000 kms',
#        '29,685 kms', '1,30,000 kms', '19,000 kms', '54,000 kms',
#        '13,000 kms', '38,200 kms', '22,000 kms', '50,000 kms',
#        '13,500 kms', '3,600 kms', '45,863 kms', '60,500 kms',
#        '12,500 kms', '18,000 kms', '13,349 kms', '29,000 kms',
#        '44,000 kms', '42,000 kms', '14,000 kms', '49,000 kms',
#        '36,200 kms', '51,000 kms', '1,04,000 kms', '33,333 kms',
# ...

# %%
car=car[car['kms_driven']!='Petrol']

# %%
car['kms_driven']=car['kms_driven'].str.replace(',','')

# %%
car['kms_driven']
# Out:
# 0       45000 kms
# 1          40 kms
# 3       28000 kms
# 4       36000 kms
# 6       41000 kms
#           ...
# 883     50000 kms
# 885     30000 kms
# 886    132000 kms
# 888     27000 kms
# 889     40000 kms
# Name: kms_driven, Length: 817, dtype: object

# %%
#checking all are in same format

import re
expected_format = r'\d+\s+kms'
valid_values = car['kms_driven'].apply(lambda x: bool(re.match(expected_format, x)))
print(valid_values.unique())
# Out:
# [ True]

# %%
#removing kms
car['kms_driven']=car['kms_driven'].str[:-4]

# %%
car['kms_driven']
# Out:
# 0       45000
# 1          40
# 3       28000
# 4       36000
# 6       41000
#         ...
# 883     50000
# 885     30000
# 886    132000
# 888     27000
# 889     40000
# Name: kms_driven, Length: 817, dtype: object

# %%
car['kms_driven']=car['kms_driven'].astype(int)
car['kms_driven']
# Out:
# 0       45000
# 1          40
# 3       28000
# 4       36000
# 6       41000
#         ...
# 883     50000
# 885     30000
# 886    132000
# 888     27000
# 889     40000
# Name: kms_driven, Length: 817, dtype: int64

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 817 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        817 non-null    object
#  1   company     817 non-null    object
#  2   year        817 non-null    int64
#  3   Price       817 non-null    int64
#  4   kms_driven  817 non-null    int64
#  5   fuel_type   816 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 44.7+ KB

# %%
car['fuel_type'].unique()
# Out:
# array(['Petrol', 'Diesel', nan, 'LPG'], dtype=object)

# %%
car['fuel_type'].dropna(inplace=True)
car['fuel_type']
# Out:
# 0      Petrol
# 1      Diesel
# 3      Petrol
# 4      Diesel
# 6      Diesel
#         ...
# 883    Petrol
# 885    Diesel
# 886    Petrol
# 888    Diesel
# 889    Diesel
# Name: fuel_type, Length: 817, dtype: object

# %%
values_to_include = ['Petrol', 'Diesel','LPG']
filtered_df = car[car['fuel_type'].isin(values_to_include)]

# %%
car=filtered_df
car.head()
# Out:
#                                      name   company  year   Price  kms_driven  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000       45000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006  425000          40
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000       28000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000       36000
# 6                               Ford Figo      Ford  2012  175000       41000
#
#   fuel_type
# 0    Petrol
# 1    Diesel
# 3    Petrol
# 4    Diesel
# 6    Diesel

# %%
sorted(car['company'].unique())
# Out:
# ['Audi',
#  'BMW',
#  'Chevrolet',
#  'Datsun',
#  'Fiat',
#  'Force',
#  'Ford',
#  'Hindustan',
#  'Honda',
#  'Hyundai',
#  'Jaguar',
#  'Jeep',
#  'Land',
#  'Mahindra',
#  'Maruti',
#  'Mercedes',
#  'Mini',
#  'Mitsubishi',
#  'Nissan',
#  'Renault',
#  'Skoda',
#  'Tata',
#  'Toyota',
#  'Volkswagen',
#  'Volvo']

# %%
car.reset_index(drop=True)
# Out:
#                                        name   company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006  425000
# 2    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000
# 3          Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000
# 4                                 Ford Figo      Ford  2012  175000
# ..                                      ...       ...   ...     ...
# 811              Maruti Suzuki Ritz VXI ABS    Maruti  2011  270000
# 812               Tata Indica V2 DLE BS III      Tata  2009  110000
# 813                    Toyota Corolla Altis    Toyota  2009  300000
# 814                     Tata Zest XM Diesel      Tata  2018  260000
# 815                      Mahindra Quanto C8  Mahindra  2013  390000
#
#      kms_driven fuel_type
# 0         45000    Petrol
# 1            40    Diesel
# 2         28000    Petrol
# 3         36000    Diesel
# ...

# %%
car['company_name']=car['name'].str.split().str[0]
car.drop('company_name',axis=1)
# Out:
# <ipython-input-168-2f8bf6aa6260>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car['company_name']=car['name'].str.split().str[0]
#                                        name   company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006  425000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000
# 4          Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000
# 6                                 Ford Figo      Ford  2012  175000
# ..                                      ...       ...   ...     ...
# 883              Maruti Suzuki Ritz VXI ABS    Maruti  2011  270000
# ...

# %%
car.describe()
# Out:
#               year         Price     kms_driven
# count   816.000000  8.160000e+02     816.000000
# mean   2012.444853  4.117176e+05   46275.531863
# std       4.002992  4.751844e+05   34297.428044
# min    1995.000000  3.000000e+04       0.000000
# 25%    2010.000000  1.750000e+05   27000.000000
# 50%    2013.000000  2.999990e+05   41000.000000
# 75%    2015.000000  4.912500e+05   56818.500000
# max    2019.000000  8.500003e+06  400000.000000

# %%
#from above distribution its not possible to have such a high diffrence in max values, so we will delete the values
#only one car above 50 lakh
car[car['Price']>5e+06]
# Out:
#                    name   company  year    Price  kms_driven fuel_type  \
# 562  Mahindra XUV500 W6  Mahindra  2014  8500003       45000    Diesel
#
#     company_name
# 562     Mahindra

# %%
car=car[car['Price']<5e+06]
car.describe()
# Out:
#               year         Price     kms_driven
# count   815.000000  8.150000e+02     815.000000
# mean   2012.442945  4.017933e+05   46277.096933
# std       4.005079  3.815888e+05   34318.459638
# min    1995.000000  3.000000e+04       0.000000
# 25%    2010.000000  1.750000e+05   27000.000000
# 50%    2013.000000  2.999990e+05   41000.000000
# 75%    2015.000000  4.900000e+05   56879.000000
# max    2019.000000  3.100000e+06  400000.000000

# %%
car.to_csv('cleaned_car.csv')

# %%
car['name']=car['name'].str.replace('Mercedes Benz','Mercedes')
car['name']=car['name'].str.replace('Hindustan Motors','Hindustan')

# %%
sorted(car['name'].unique())
# Out:
# ['Audi A3 Cabriolet 40 TFSI',
#  'Audi A4 1.8 TFSI Multitronic Premium Plus',
#  'Audi A4 2.0 TDI 177bhp Premium',
#  'Audi A6 2.0 TDI Premium',
#  'Audi A8',
#  'Audi Q3 2.0 TDI quattro Premium',
#  'Audi Q5 2.0 TDI quattro Premium Plus',
#  'Audi Q7',
#  'BMW 3 Series 320d Sedan',
#  'BMW 3 Series 320i',
#  'BMW 5 Series 520d Sedan',
#  'BMW 5 Series 530i',
#  'BMW 7 Series 740Li Sedan',
#  'BMW X1',
#  'BMW X1 sDrive20d',
#  'BMW X1 xDrive20d xLine',
#  'Chevrolet Beat',
#  'Chevrolet Beat Diesel',
#  'Chevrolet Beat LS Diesel',
#  'Chevrolet Beat LS Petrol',
#  'Chevrolet Beat LT Diesel',
#  'Chevrolet Beat LT Opt Diesel',
#  'Chevrolet Beat LT Petrol',
#  'Chevrolet Beat PS Diesel',
#  'Chevrolet Cruze LTZ',
#  'Chevrolet Cruze LTZ AT',
#  'Chevrolet Enjoy',
#  'Chevrolet Enjoy 1.4 LS 8 STR',
#  'Chevrolet Sail 1.2 LS',
#  'Chevrolet Sail UVA Petrol LT ABS',
#  'Chevrolet Spark',
#  'Chevrolet Spark 1.0 LT',
#  'Chevrolet Spark LS 1.0',
#  'Chevrolet Spark LT 1.0',
# ...

# %%
car['name']=car['name'].str.replace('','Maruthi')

# %%
#taking first 3 words of each carnmae
car['name'] = car['name'].str.split().str[:3].apply(' '.join)
car.head()
# Out:
#                      name   company  year   Price  kms_driven fuel_type  \
# 0     Hyundai Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1     Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 3       Hyundai Grand i10   Hyundai  2014  325000       28000    Petrol
# 4  Ford EcoSport Titanium      Ford  2014  575000       36000    Diesel
# 6               Ford Figo      Ford  2012  175000       41000    Diesel
#
#   company_name
# 0      Hyundai
# 1     Mahindra
# 3      Hyundai
# 4         Ford
# 6         Ford

# %% [markdown]
# <h><b>MODEL BUILDING

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

# %%
label_encoders = {}
for column_name in ['name','company','fuel_type']:
    le = LabelEncoder()
    car[column_name] = le.fit_transform(car[column_name])
    label_encoders[column_name] = le

print(car)
# Out:
#      name  company  year   Price  kms_driven  fuel_type company_name
# 0      92        9  2007   80000       45000          2      Hyundai
# 1     119       13  2006  425000          40          0     Mahindra
# 3      89        9  2014  325000       28000          2      Hyundai
# 4      40        6  2014  575000       36000          0         Ford
# 6      45        6  2012  175000       41000          0         Ford
# ..    ...      ...   ...     ...         ...        ...          ...
# 883   191       14  2011  270000       50000          2       Maruti
# 885   250       21  2009  110000       30000          0         Tata
# 886   278       22  2009  300000      132000          2       Toyota
# 888   276       21  2018  260000       27000          0         Tata
# 889   126       13  2013  390000       40000          0     Mahindra
#
# [815 rows x 7 columns]

# %%
car.drop('company_name',axis=1)
# Out:
#      name  company  year   Price  kms_driven  fuel_type
# 0      92        9  2007   80000       45000          2
# 1     119       13  2006  425000          40          0
# 3      89        9  2014  325000       28000          2
# 4      40        6  2014  575000       36000          0
# 6      45        6  2012  175000       41000          0
# ..    ...      ...   ...     ...         ...        ...
# 883   191       14  2011  270000       50000          2
# 885   250       21  2009  110000       30000          0
# 886   278       22  2009  300000      132000          2
# 888   276       21  2018  260000       27000          0
# 889   126       13  2013  390000       40000          0
#
# [815 rows x 6 columns]

# %%
x= car.drop(columns=['Price','company_name'])
y=car['Price']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 178716585397.95624

# %%
r2_score(y_test,y_pred)
# Out:
# 0.12239386583887601

# %% [markdown]
# <b>PREDICTION

# %%
new_data = {'': ['Toyota'],
            'mileage': [27]}  # Provide feature values for prediction
df_new = pd.DataFrame(new_data)
df_new_encoded = pd.get_dummies(df_new, columns=['car_brand'], drop_first=True)
predicted_price = model.predict(df_new_encoded)

# Display the predicted price
print("Predicted Price:", predicted_price)
